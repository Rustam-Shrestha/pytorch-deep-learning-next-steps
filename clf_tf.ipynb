# %% [markdown]
# Image whole image changed to 1d vector of 10x10 shape and now we put each of thefeatures in input layers hidden layer will process it
# as image is in right shape size and fed it will certainly recognize but if it tilts distorts or any transformation done it will b edisarster to linear models as it wont be ablt to generalize
# thats where nonlinear comes in
#
# neuron takes receptive field as two dimensional field
#
# like what is convulving meaning what is mean of it what if  we do more convulving in image what is outcome??
#
# convolution nn can do irrelevant calculations leading to insanely costly computation
# solution is pooling
# max pooling
# feature map with 2x2 pool but it is not weighted kernel
# bring highest value of each 2x2 within 2x2 so for each 2x2 grid take most significat bright pixel take it and set it
# issue is the invariance-might be complex later
#
# average pooling
# just 4 element its average than maximum
# not suitable for invariance
#
# depth pooling
# handles invariance too
#
#
# images can be different type
#
# rgb hsv hsl grayscale  infrared saellite channels and more...

# %% [markdown]
# ![image.png](attachment:92bc262e-3e7a-4eb4-8afc-5b30a2ecae30.png)
#
# ![image.png](attachment:dfd7805a-2421-4844-a7bb-dd8d31648c76.png)
#
# ![image.png](attachment:4f471c90-bdd1-4639-889c-ddb3b00041e4.png)
